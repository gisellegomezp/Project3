# %% [markdown]
# # Data Prep
# This first section is used for reading in raw data files and creating subsets of data that can be used for development

# %%
import pandas as pd
import json
import random
import ast
import requests
import io
import os
import platform

# %%
# set folder path to data when using Linux or Windows
# if os.name == 'posix' or platform.system() == 'Linux':  # For Ubuntu/Linux
#     folder_path = "../Project Main/data/"
# elif os.name == 'nt' or platform.system() == 'Windows':  # For Windows
#     folder_path = "..\\Project Main\\data\\"

if os.name == 'posix' or platform.system() == 'Linux':  # For Ubuntu/Linux
    path_char = "/"
elif os.name == 'nt' or platform.system() == 'Windows':  # For Windows
    path_char = "\\"

# %%
# read in jsonl files for all Appliances reviews
data = []
file = '..'+path_char+'..'+path_char+'Appliances.jsonl'
with open(file, 'r') as fp:
    for line in fp:
        data.append(json.loads(line.strip()))

# %%
# read in jsonl files for meta_Appliances for all products
meta_data = []
file = '..'+path_char+'..'+path_char+'meta_Appliances.jsonl'
with open(file, 'r') as fp:
    for line in fp:
        meta_data.append(json.loads(line.strip()))

# %%
# look at size of datasets
print("data length: ", len(data))
print("meta data lenth: ", len(meta_data))
# Out:
# data length:  2128605
# meta data lenth:  94327

# %%
# define function to split data into chunks
def split_list(data, chunk_size):
    # Shuffle the data randomly
    random.shuffle(data)
    
    # Split the list into chunks of specified size
    return [data[i:i + chunk_size] for i in range(0, len(data), chunk_size)]

# spit data into smaller chunks
smaller_lists_appliances = split_list(data, 200000)
smaller_lists_meta = split_list(meta_data, 30000)

# %%
# save smaller appliance files
for i, chunk in enumerate(smaller_lists_appliances):
    # Define the filename for each chunk (e.g., "list_1.txt", "list_2.txt", etc.)
    filename = 'data'+path_char+f'Appliances_{i+1}.txt'
    with open(filename, 'w') as file:
        # Write each item from the list to a new line in the file
        file.write('\n'.join(map(str, chunk)))

# %%
# save smaller meta files 
for i, chunk in enumerate(smaller_lists_meta):
    # Define the filename for each chunk (e.g., "list_1.txt", "list_2.txt", etc.)
    filename = 'data'+path_char+f'meta_{i+1}.txt'
    with open(filename, 'w') as file:
        # Write each item from the list to a new line in the file
        file.write('\n'.join(map(str, chunk)))

# %%
# # read in smaller Appliance and meta files
# with open('..'+path_char+'Project Main'+path_char+'data'+path_char+'Appliances_1.txt', 'r') as file:
#     appliances = file.read().splitlines()  
# with open('..'+path_char+'Project Main'+path_char+'data'+'path_char'+path_char+'meta_4.txt', 'r') as file:
#     meta = file.read().splitlines()  

# # put Appliance and meta data into data frames
# parsed_data = [ast.literal_eval(item) for item in appliances]
# df_appliance = pd.DataFrame(parsed_data)

# parsed_data = [ast.literal_eval(item) for item in meta]
# df_meta = pd.DataFrame(parsed_data)

# %%
# read in all files and create a dataframe, then save to parquet file
df_appliances = []
df_metas = []

#combine all appliance files
for i in range(1, 11 + 1):
    print(f"Appliance file: {i}")
    filename = '..'+path_char+'Project Main'+path_char+'data'+path_char+f'Appliances_{i}.txt'
    with open(filename, 'r') as file:
        appliances = file.read().splitlines()  

    parsed_data = [ast.literal_eval(item) for item in appliances]
    df_appliance = pd.DataFrame(parsed_data)

    df_appliances.append(df_appliance)

# combine all meta files
for i in range(1, 4 + 1):
    print(f"meta file: {i}")
    filename = '..'+path_char+'Project Main'+path_char+'data'+path_char+f'meta_{i}.txt'
    with open(filename, 'r') as file:
        meta = file.read().splitlines()  

    parsed_data = [ast.literal_eval(item) for item in meta]
    df_meta = pd.DataFrame(parsed_data)

    df_metas.append(df_meta)

combined_df_appliance = pd.concat(df_appliances, ignore_index=True)
combined_df_meta = pd.concat(df_metas, ignore_index=True)

#write large data frames to parquet files
combined_df_appliance.to_parquet('..'+path_char+'..'+path_char+'Appliance_file_large.parquet',compression='Brotli', engine='pyarrow')
combined_df_meta.to_parquet('..'+path_char+'..'+path_char+'meta_file_large.parquet', compression='Brotli',engine='pyarrow')
# Out:
# Appliance file: 1
# Appliance file: 2
# Appliance file: 3
# Appliance file: 4
# Appliance file: 5
# Appliance file: 6
# Appliance file: 7
# Appliance file: 8
# Appliance file: 9
# Appliance file: 10
# Appliance file: 11
# meta file: 1
# meta file: 2
# meta file: 3
# meta file: 4

# %%
# this code can be used to pull the combined large datafiles from google drive.  The file format is parquet.

import gdown  # for downloading from google drive

# pull large Appliance files from google drive
file_id = '17-NNDAjDtI-PhQJ2P8U-O-l9sZhI71rp'
download_url = f'https://drive.google.com/uc?id={file_id}'
gdown.download(download_url, 'downloaded_file.parquet', quiet=False)
Appliance_file_large = pd.read_parquet('downloaded_file.parquet')

# Display the dataframe
Appliance_file_large.head()

# pull large meta file from google drive
file_id = '19F34NIW3QVfzd1g7BuhR6DBiFHbSVRbH'
download_url = f'https://drive.google.com/uc?export=download&id={file_id}'
response = requests.get(download_url)
response.raise_for_status()  
file_content = io.BytesIO(response.content)
meta_file_large = pd.read_parquet(file_content)

# Display the dataframe
meta_file_large.head()

# %%
# read in large dataset from parquet to confirm correct
meta_df_read_large = pd.read_parquet('..'+path_char+'..'+path_char+'meta_file_large.parquet', engine='pyarrow')
meta_df_read_large
# Out:
#                   main_category  \
# 0                    Appliances
# 1      Tools & Home Improvement
# 2                          None
# 3                    Appliances
# 4                    Appliances
# ...                         ...
# 94322  Tools & Home Improvement
# 94323  Tools & Home Improvement
# 94324  Tools & Home Improvement
# 94325  Tools & Home Improvement
# 94326                Appliances
#
#                                                    title  average_rating  \
# 0      5304514664 Range Oven Control Board (Replaces ...             5.0
# 1                      GE WH01X20826 Washer Shock Damper             4.8
# 2      Refrigerator Ice Maker Assembly for Samsung DA...             3.0
# 3      La Cuisine 30" Wall Mount Stainless Steel Glas...             4.0
# 4      4 Pack W10311524 Air Filter Replacement For Wh...             4.5
# ...                                                  ...             ...
# 94322    GE Part# WR30X10150 Door Mounted Icemaker (OEM)             4.0
# 94323  312959 Dryer Belt Replacement for Maytag LDE73...             4.1
# 94324      Whirlpool W10177965 Surface Element for Range             2.0
# 94325  Cheliq Egg Holder with Lid, BPA Free and Dishw...             4.0
# 94326  LG Electronics MEA49050001 Dryer Lint Filter F...             4.3
#
#        rating_number                                           features  \
# 0                  1                                                 []
# 1                 10  [The GE WH01X20826 is a genuine OEM Shock Damp...
# 2                  1                                                 []
# 3                  4  [5 Layer Stainless Steel Baffle Filters. Dishw...
# 4                129  [Part Number: W10311524, Replaces: 2319308, W1...
# ...              ...                                                ...
# 94322             22  [This is an O.E.M. Authorized part, Fits with ...
# 94323              4  [UpStart Components Replacement 312959 Dryer B...
# 94324              1  [Works with the following models: Whirlpool WF...
# 94325             32  [Made of food grade PP material, Transparent e...
# 94326            264  [Dryer lint filter frame/guide, Used for some ...
#
#                                              description   price  \
# 0                                                     []  307.95
# 1      [The GE WH01X20826 is a genuine OEM Shock Damp...   26.23
# 2                                                     []     NaN
# 3      [This 30" wall mount range hood Glass features...     NaN
# 4      [Specifications:, Dimension: 3 x 1.8 x 0.5 inc...   14.99
# ...                                                  ...     ...
# 94322  [This is an O.E.M. Authorized part. Fits with ...  139.99
# 94323  [UpStart Components Replacement 312959 Dryer B...    7.99
# 94324  [From the Manufacturer, Whirlpool W10177965 Su...     NaN
# 94325  [Cheliq Egg Holder with Lid, BPA Free and Dish...     NaN
# 94326  [Product Description, LG MEA49050001 Dryer Lin...    9.99
#
#                                                   images  \
# 0      [{'hi_res': 'https://m.media-amazon.com/images...
# 1      [{'hi_res': 'https://m.media-amazon.com/images...
# 2      [{'hi_res': 'https://m.media-amazon.com/images...
# 3      [{'hi_res': 'https://m.media-amazon.com/images...
# 4      [{'hi_res': 'https://m.media-amazon.com/images...
# ...                                                  ...
# 94322  [{'hi_res': 'https://m.media-amazon.com/images...
# 94323  [{'hi_res': 'https://m.media-amazon.com/images...
# 94324  [{'hi_res': None, 'large': 'https://m.media-am...
# 94325  [{'hi_res': 'https://m.media-amazon.com/images...
# 94326  [{'hi_res': None, 'large': 'https://m.media-am...
#
#                                                   videos  \
# 0                                                     []
# 1      [{'title': 'Welcome  to  TOMOON', 'url': 'http...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 94322  [{'title': '241798224 Ice Maker for Electrolux...
# 94323                                                 []
# 94324                                                 []
# 94325                                                 []
# 94326                                                 []
#
#                        store  \
# 0                 Frigidaire
# 1                         GE
# 2                 wshrapplns
# 3                 LA CUISINE
# 4      Discount Parts Direct
# ...                      ...
# 94322       General Electric
# 94323     UpStart Components
# 94324              Whirlpool
# 94325                 CHELIQ
# 94326                     LG
#
#                                               categories  \
# 0                                                     []
# 1                      [Appliances, Parts & Accessories]
# 2      [Appliances, Parts & Accessories, Refrigerator...
# 3      [Appliances, Ranges, Ovens & Cooktops, Range H...
# 4      [Appliances, Parts & Accessories, Refrigerator...
# ...                                                  ...
# 94322  [Appliances, Parts & Accessories, Refrigerator...
# 94323                  [Appliances, Parts & Accessories]
# 94324  [Appliances, Parts & Accessories, Range Parts ...
# 94325  [Appliances, Parts & Accessories, Refrigerator...
# 94326  [Appliances, Parts & Accessories, Dryer Parts ...
#
#                                                  details parent_asin  \
# 0      {'': None, 'AC Adapter Current': None, 'Access...  B07B3M5KRX
# 1      {'': None, 'AC Adapter Current': None, 'Access...  B01M7TMMTL
# 2      {'': None, 'AC Adapter Current': None, 'Access...  B07PNVNK7X
# 3      {'': None, 'AC Adapter Current': None, 'Access...  B01C7I9Z1W
# 4      {'': None, 'AC Adapter Current': None, 'Access...  B07QLB1CYC
# ...                                                  ...         ...
# 94322  {'': None, 'AC Adapter Current': None, 'Access...  B00ZJRD7RW
# 94323  {'': None, 'AC Adapter Current': None, 'Access...  B07S8724TT
# 94324  {'': None, 'AC Adapter Current': None, 'Access...  B005ARBA3E
# 94325  {'': None, 'AC Adapter Current': None, 'Access...  B09B2ZJTHH
# 94326  {'': None, 'AC Adapter Current': None, 'Access...  B00AF7W7N6
#
#       bought_together subtitle author
# 0                None     None   None
# 1                None     None   None
# 2                None     None   None
# 3                None     None   None
# 4                None     None   None
# ...               ...      ...    ...
# 94322            None     None   None
# 94323            None     None   None
# 94324            None     None   None
# 94325            None     None   None
# 94326            None     None   None
#
# [94327 rows x 16 columns]

# %%
#randomly select a subset of appliance data that can be used for development.  A larger dataset will be used once model is developed

#choose random subset
subset_appliances = split_list(data, 50000)
subset_appliances_df = pd.DataFrame(subset_appliances[0])

# find unique asin's from subset of data
asin_unique= subset_appliances_df['parent_asin'].unique()
subset_meta_df = meta_df_read_large.loc[meta_df_read_large['parent_asin'].isin(asin_unique)]

# save subset to parquet files
subset_meta_df.to_parquet('..'+path_char+'Project Main'+path_char+'data'+path_char+'meta_file_subset.parquet', compression='Brotli',engine='pyarrow')
subset_appliances_df.to_parquet('..'+path_char+'Project Main'+path_char+'data'+path_char+'Appliance_file_subset.parquet', compression='Brotli',engine='pyarrow')
subset_meta_df.head()
# Out:
#                main_category  \
# 14  Tools & Home Improvement
# 23               Amazon Home
# 27                Appliances
# 33  Tools & Home Improvement
# 35  Tools & Home Improvement
#
#                                                 title  average_rating  \
# 14  EXCELPURE GXRTDR Inline Water Filter Replaceme...             4.7
# 23  TrulyAll Disposable Single Serve Pour-Over Cof...             4.2
# 27                             LG AEH36821908 , BLACK             4.5
# 33  Upgraded 5301EL1001A Dryer Heating Element Ass...             4.0
# 35  Supco DE902M Dryer Door Latch Kit Replaces Whi...             3.8
#
#     rating_number                                           features  \
# 14            146  [❄️EXCEL.QUALITY - NSF Certified Carbon Filter...
# 23             44  [Quickly brew your favorite drink anytime, any...
# 27             12  [Country Of Origin: United States, Model Numbe...
# 33            282  [🛒 PREMIUM METAL MATERIAL -- The 5301EL1001A d...
# 35            132  [DRYER DOOR LATCH - This premium quality part ...
#
#                                           description  price  \
# 14                                                 []  31.99
# 23                                                 []    NaN
# 27  [This is a Genuine replacement LG part. Please...  35.79
# 33                                                 []  52.77
# 35  [Product Description, Supco DE902M Dryer Door ...   6.98
#
#                                                images  \
# 14  [{'hi_res': 'https://m.media-amazon.com/images...
# 23  [{'hi_res': 'https://m.media-amazon.com/images...
# 27  [{'hi_res': 'https://m.media-amazon.com/images...
# 33  [{'hi_res': 'https://m.media-amazon.com/images...
# 35  [{'hi_res': 'https://m.media-amazon.com/images...
#
#                                                videos      store  \
# 14  [{'title': 'WD-INL Installation Instructions',...  EXCELPURE
# 23                                                 []   TrulyAll
# 27                                                 []         LG
# 33  [{'title': '5301EL1001J Dryer Heating Element'...    Sikawai
# 35  [{'title': 'Supplying Demand 279570B Product 3...      Supco
#
#                                            categories  \
# 14  [Appliances, Parts & Accessories, Refrigerator...
# 23  [Small Appliance Parts & Accessories, Coffee &...
# 27                  [Appliances, Parts & Accessories]
# 33  [Appliances, Parts & Accessories, Dryer Parts ...
# 35  [Appliances, Parts & Accessories, Dryer Parts ...
#
#                                               details parent_asin  \
# 14  {'': None, 'AC Adapter Current': None, 'Access...  B07MCH6W31
# 23  {'': None, 'AC Adapter Current': None, 'Access...  B01IBXADOK
# 27  {'': None, 'AC Adapter Current': None, 'Access...  B00I8VIYBK
# 33  {'': None, 'AC Adapter Current': None, 'Access...  B08C7H18YP
# 35  {'': None, 'AC Adapter Current': None, 'Access...  B00GS9DPJA
#
#    bought_together subtitle author
# 14            None     None   None
# 23            None     None   None
# 27            None     None   None
# 33            None     None   None
# 35            None     None   None

# %% [markdown]
# # Reviews prep for model
# This section is used to prep the data from evaluation in the model

# %%
# load libraries
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')

# define characters to remove and stop words
regex = re.compile("[^a-zA-Z ]")
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /home/mike/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/mike/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# function to process reviews
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = regex.sub(' ', text) # Substitute everything that is not a letter with an empty string
    words = word_tokenize(text) # tokenize text
    words = [word for word in words if word not in stop_words]  # Remove stopwords
    return words


# read in subset of data files
meta_subset_df = pd.read_parquet('..'+path_char+'Project Main'+path_char+'data'+path_char+'meta_file_subset.parquet', engine='pyarrow')
Appliance_subset_df = pd.read_parquet('..'+path_char+'Project Main'+path_char+'data'+path_char+'Appliance_file_subset.parquet', engine='pyarrow')


# Apply the preprocessing function to your text column
Appliance_subset_df['text_clean'] = Appliance_subset_df['text'].apply(preprocess_text)

# %%
# view raw vs processed reviews
Appliance_subset_df[['text','text_clean']]
# Out:
#                                                     text  \
# 0                                       Quality Product.
# 1                                     Works as expected.
# 2      These filters are a perfect fit for my Vornado...
# 3      This filter was just as good as the original o...
# 4      Liked everything about k cups. These are much ...
# ...                                                  ...
# 49995  It fits and works perfectly on my fridge with ...
# 49996  I had on of the gold mesh/plastic framed filte...
# 49997  Perfect to replace cheap aluminum ones on our ...
# 49998                                               nice
# 49999  Belts worked great and saved me alot of time a...
#
#                                               text_clean
# 0                                     [quality, product]
# 1                                      [works, expected]
# 2      [filters, perfect, fit, vornado, looks, like, ...
# 3      [filter, good, original, one, came, coffee, ma...
# 4      [liked, everything, k, cups, much, easier, cle...
# ...                                                  ...
# 49995  [fits, works, perfectly, fridge, added, conven...
# 49996  [gold, mesh, plastic, framed, filters, years, ...
# 49997  [perfect, replace, cheap, aluminum, ones, euro...
# 49998                                             [nice]
# 49999   [belts, worked, great, saved, alot, time, money]
#
# [50000 rows x 2 columns]

# %% [markdown]
# # flatten meta data
# This section flattens the meta data.  Categores is a list of all products and needs to be flattened in order to use.

# %%
# define a list of products to be used as part of the app
my_list = ['Dishwashers','Freezers','Ranges','Ice Makers','Cooktops','Refrigerators','Beverage Refrigerators','Dryers','Washers']

# remove parts and accessories from data
mask = ~meta_subset_df.apply(lambda col: col.map(lambda x: 'Parts & Accessories' in str(x))).any(axis=1)
filtered_meta_df = meta_subset_df[mask]

# select specific items
mask = filtered_meta_df.apply(lambda col: col.map(lambda x: any(item in str(x) for item in my_list))).any(axis=1)

# create a dataframe of filtered dataset
filtered_meta_df = filtered_meta_df[mask]
filtered_meta_df.head()
# Out:
#                main_category  \
# 111               Appliances
# 116               Appliances
# 362              Amazon Home
# 642               Appliances
# 723  Industrial & Scientific
#
#                                                  title  average_rating  \
# 111  Igloo Premium Self-Cleaning Countertop Ice Mak...             4.4
# 116  Whirlpool WDT720PADM Built-in Stainless Dishwa...             2.7
# 362  GE Profile : PHB925SPSS 30 Freestanding Induct...             2.3
# 642  QUNYI Mini Washing Machine, Portable Foldable ...             2.0
# 723  VIVOHOME Electric Portable Compact Countertop ...             4.4
#
#      rating_number                                           features  \
# 111           2410  [Note : Please check the dimension and item we...
# 116              8                                                 []
# 362             11                                                 []
# 642             27                                                 []
# 723           8025  [LIGHTWEIGHT & PORTABLE - Lightweight feature ...
#
#                                            description   price  \
# 111  [Say hello the Igloo 26-pound countertop ice m...  183.09
# 116                                                 []     NaN
# 362  [GE Consumer and Industrial spans the globe as...     NaN
# 642  [🧦QUNYI Mini Washing Machine is the best assis...     NaN
# 723                                                 []  139.99
#
#                                                 images  \
# 111  [{'hi_res': 'https://m.media-amazon.com/images...
# 116  [{'hi_res': 'https://m.media-amazon.com/images...
# 362  [{'hi_res': None, 'large': 'https://m.media-am...
# 642  [{'hi_res': 'https://m.media-amazon.com/images...
# 723  [{'hi_res': 'https://m.media-amazon.com/images...
#
#                                                 videos      store  \
# 111  [{'title': 'Our Point of View on Igloo Counter...      Igloo
# 116                                                 []  Whirlpool
# 362                                                 []         GE
# 642                                                 []      QUNYI
# 723  [{'title': 'HONEST Review of VIVOHOME Electric...   VIVOHOME
#
#                                             categories  \
# 111  [Appliances, Refrigerators, Freezers & Ice Mak...
# 116    [Appliances, Dishwashers, Built-In Dishwashers]
# 362  [Appliances, Ranges, Ovens & Cooktops, Ranges,...
# 642                                                 []
# 723  [Appliances, Refrigerators, Freezers & Ice Mak...
#
#                                                details parent_asin  \
# 111  {'': None, 'AC Adapter Current': None, 'Access...  B0BXHCDWM8
# 116  {'': None, 'AC Adapter Current': None, 'Access...  B00NVKRTIW
# 362  {'': None, 'AC Adapter Current': None, 'Access...  B002KGKNYU
# 642  {'': None, 'AC Adapter Current': None, 'Access...  B09KB8SMJ6
# 723  {'': None, 'AC Adapter Current': None, 'Access...  B0BLC6GRLX
#
#     bought_together subtitle author
# 111            None     None   None
# 116            None     None   None
# 362            None     None   None
# 642            None     None   None
# 723            None     None   None

# %%
# flatten the categories field into individual columns

# create a df of just categories
df = pd.DataFrame(filtered_meta_df['categories'])
 
# Convert the list in the categories column to strings to work with the values
df['categories'] = df['categories'].apply(lambda x: ', '.join(x))

# Split the lists into unique categories
unique_categories = set([item for sublist in df['categories'].str.split(', ') for item in sublist])

# Create new columns for each unique category
for category in unique_categories:
    df[category] = df['categories'].apply(lambda x: 1 if category in x else 0)

#concat the two, original and flattened
meta_subset_flat_df = pd.concat([filtered_meta_df,df],axis=1)
meta_subset_flat_df.head()
# Out:
#                main_category  \
# 111               Appliances
# 116               Appliances
# 362              Amazon Home
# 642               Appliances
# 723  Industrial & Scientific
#
#                                                  title  average_rating  \
# 111  Igloo Premium Self-Cleaning Countertop Ice Mak...             4.4
# 116  Whirlpool WDT720PADM Built-in Stainless Dishwa...             2.7
# 362  GE Profile : PHB925SPSS 30 Freestanding Induct...             2.3
# 642  QUNYI Mini Washing Machine, Portable Foldable ...             2.0
# 723  VIVOHOME Electric Portable Compact Countertop ...             4.4
#
#      rating_number                                           features  \
# 111           2410  [Note : Please check the dimension and item we...
# 116              8                                                 []
# 362             11                                                 []
# 642             27                                                 []
# 723           8025  [LIGHTWEIGHT & PORTABLE - Lightweight feature ...
#
#                                            description   price  \
# 111  [Say hello the Igloo 26-pound countertop ice m...  183.09
# 116                                                 []     NaN
# 362  [GE Consumer and Industrial spans the globe as...     NaN
# 642  [🧦QUNYI Mini Washing Machine is the best assis...     NaN
# 723                                                 []  139.99
#
#                                                 images  \
# 111  [{'hi_res': 'https://m.media-amazon.com/images...
# 116  [{'hi_res': 'https://m.media-amazon.com/images...
# 362  [{'hi_res': None, 'large': 'https://m.media-am...
# 642  [{'hi_res': 'https://m.media-amazon.com/images...
# 723  [{'hi_res': 'https://m.media-amazon.com/images...
#
#                                                 videos      store  ...  \
# 111  [{'title': 'Our Point of View on Igloo Counter...      Igloo  ...
# 116                                                 []  Whirlpool  ...
# 362                                                 []         GE  ...
# 642                                                 []      QUNYI  ...
# 723  [{'title': 'HONEST Review of VIVOHOME Electric...   VIVOHOME  ...
#
#     Beverage Refrigerators Washers Dryers Built-In Dishwashers  \
# 111                      0       0      0                    0
# 116                      0       0      0                    1
# 362                      0       0      0                    0
# 642                      0       0      0                    0
# 723                      0       0      0                    0
#
#     Washers & Dryers Appliances Portable Washers  \
# 111                0          1                0
# 116                0          1                0
# 362                0          1                0
# 642                0          0                0
# 723                0          1                0
#
#      Stacked Washer & Dryer Units  Freezers & Ice Makers  Wall Ovens
# 111                             0                      1           0
# 116                             0                      0           0
# 362                             0                      0           0
# 642                             0                      0           0
# 723                             0                      1           0
#
# [5 rows x 49 columns]

# %%
# look at columns in flattened meta dataframe
meta_subset_flat_df.columns
# Out:
# Index(['main_category', 'title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'images', 'videos', 'store', 'categories',
#        'details', 'parent_asin', 'bought_together', 'subtitle', 'author',
#        'categories', '', 'All-in-One Combination Washers & Dryers',
#        'Dishwashers', 'Slide-In Ranges', 'Upright Freezers', 'Kegerators',
#        'Freezers', 'Countertop Dishwashers', 'Ranges', 'Single Wall Ovens',
#        'Laundry Appliances', 'Portable Dryers', 'Range Hoods',
#        'Double Wall Ovens', 'Cooktops', 'Ice Makers', 'Ovens & Cooktops',
#        'Combination Microwave & Wall Ovens', 'Freestanding Ranges',
#        'Portable Dishwashers', 'Chest Freezers', 'Refrigerators',
#        'Beverage Refrigerators', 'Washers', 'Dryers', 'Built-In Dishwashers',
#        'Washers & Dryers', 'Appliances', 'Portable Washers',
#        'Stacked Washer & Dryer Units', 'Freezers & Ice Makers', 'Wall Ovens'],
#       dtype='object')

# %%
# function to find top 3 and bottom 3 reviews
def find_top_bottom(Appliance_df,meta_flat_df,product_type):
    # find meta data that match product type
    selected_product = meta_flat_df[(meta_flat_df[product_type]==1)]['parent_asin'].unique()
    # find reviews that match product type
    reviews_with_match_product = Appliance_df[Appliance_df['parent_asin'].isin(selected_product)]
    # calculate the mean rating for each parent_asin or product type
    product_ratings_means = reviews_with_match_product.groupby('parent_asin')['rating'].mean().sort_values(ascending=False).reset_index()
    # find top 3 and bottom 3
    top3 = product_ratings_means[:].head(3)['parent_asin']
    bottom3 = product_ratings_means[:].tail(3)['parent_asin']
    # return top 3 and bottom 3 products
    return meta_subset_df[meta_subset_df['parent_asin'].isin(top3)], meta_subset_df[meta_subset_df['parent_asin'].isin(bottom3)]


top3,bottom3 = find_top_bottom(Appliance_subset_df,meta_subset_flat_df,product_type='Chest Freezers')

# %%
# view top 3
top3
# Out:
#                    main_category  \
# 3724                  Appliances
# 6699                  Appliances
# 80093  Cell Phones & Accessories
#
#                                                    title  average_rating  \
# 3724   Haier HF50CM23NW 5.0 cu. ft. Capacity Chest Fr...             4.4
# 6699   Commercial Top Chest Freezer - KITMA 9.6 Cu. F...             4.3
# 80093                                  Headphone Adapter             4.5
#
#        rating_number                                           features  \
# 3724             237  [Holds up to 175lbs of frozen food, Adjustable...
# 6699              21                              [KITMA CHEST FREEZER]
# 80093             27  [Soft 2HB graphite core gives you a superb smo...
#
#                                              description  price  \
# 3724   [Storage for up to 175 lbs. Storage space to a...    NaN
# 6699                     [Kitma 9.6 Cu.Ft Chest Freezer]    NaN
# 80093  [Miukada half pencil, has been pre-sharpened t...    NaN
#
#                                                   images videos    store  \
# 3724   [{'hi_res': 'https://m.media-amazon.com/images...     []    Haier
# 6699   [{'hi_res': 'https://m.media-amazon.com/images...     []    KITMA
# 80093  [{'hi_res': 'https://m.media-amazon.com/images...     []  Miukada
#
#                                               categories  \
# 3724   [Appliances, Refrigerators, Freezers & Ice Mak...
# 6699   [Appliances, Refrigerators, Freezers & Ice Mak...
# 80093  [Appliances, Refrigerators, Freezers & Ice Mak...
#
#                                                  details parent_asin  \
# 3724   {'': None, 'AC Adapter Current': None, 'Access...  B0198ZXHEI
# 6699   {'': None, 'AC Adapter Current': None, 'Access...  B07GLKMY7G
# 80093  {'': None, 'AC Adapter Current': None, 'Access...  B07GWWQK2M
#
#       bought_together subtitle author
# 3724             None     None   None
# 6699             None     None   None
# 80093            None     None   None

# %%
# view bottom 3
bottom3
# Out:
#                   main_category  \
# 55056  Tools & Home Improvement
# 68576                Appliances
# 87504                      None
#
#                                                    title  average_rating  \
# 55056  ZUYIYI Mini Chest Freezer Cover, Outdoor Deep ...             4.7
# 68576  COSTWAY 105 Quart Car Travel Freezer, Portable...             3.2
# 87504  Magic Chef MCCF35WBX 3.5 Cubic Feet Chest Freezer             3.3
#
#        rating_number                                           features  \
# 55056             10  [✅【HIGH QUALITY】Made of 420D Oxford Fabric wit...
# 68576              7  [🐟【Large Capacity & Perfect Portability: 】With...
# 87504              8  [3.5 cubic feet capacity, Adjustable thermosta...
#
#                                              description  price  \
# 55056                                                 []  20.99
# 68576  [Description:, This portable vehicle refrigera...    NaN
# 87504  [3.5 Cubic Feet Capacity; Adjustable Thermosta...    NaN
#
#                                                   images videos       store  \
# 55056  [{'hi_res': 'https://m.media-amazon.com/images...     []      ZUYIYI
# 68576  [{'hi_res': 'https://m.media-amazon.com/images...     []     COSTWAY
# 87504  [{'hi_res': 'https://m.media-amazon.com/images...     []  Magic Chef
#
#                                               categories  \
# 55056  [Appliances, Refrigerators, Freezers & Ice Mak...
# 68576  [Appliances, Refrigerators, Freezers & Ice Mak...
# 87504  [Appliances, Refrigerators, Freezers & Ice Mak...
#
#                                                  details parent_asin  \
# 55056  {'': None, 'AC Adapter Current': None, 'Access...  B0BCKGRW6Y
# 68576  {'': None, 'AC Adapter Current': None, 'Access...  B07VPDJQ5Y
# 87504  {'': None, 'AC Adapter Current': None, 'Access...  B007ZT2XU4
#
#       bought_together subtitle author
# 55056            None     None   None
# 68576            None     None   None
# 87504            None     None   None

# %% [markdown]
# # Run dataset against model
# This section runs all the reviews agains the newly trained roberta model
